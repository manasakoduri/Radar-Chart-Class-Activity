# %% [markdown]
# <a href="https://colab.research.google.com/github/manasakoduri/Radar-Chart-Class-Activity/blob/main/ManasaK_RadarChart_Class_Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import math


AA=pd.DataFrame(columns = ['criteria','weight','ratingA','ratingB','scoreA','scoreB'])

# %%
AA['criteria'] = ['risk', 'ROI','customerSatisfaction','feasibility','strategicAlignment']

print(AA)
# Out:
#                criteria weight ratingA ratingB scoreA scoreB
# 0                  risk    NaN     NaN     NaN    NaN    NaN
# 1                   ROI    NaN     NaN     NaN    NaN    NaN
# 2  customerSatisfaction    NaN     NaN     NaN    NaN    NaN
# 3           feasibility    NaN     NaN     NaN    NaN    NaN
# 4    strategicAlignment    NaN     NaN     NaN    NaN    NaN

# %%
AA['weight'] = [0.15,0.15,0.2,0.4,0.1]
print(AA)
# Out:
#                criteria  weight ratingA ratingB scoreA scoreB
# 0                  risk    0.15     NaN     NaN    NaN    NaN
# 1                   ROI    0.15     NaN     NaN    NaN    NaN
# 2  customerSatisfaction    0.20     NaN     NaN    NaN    NaN
# 3           feasibility    0.40     NaN     NaN    NaN    NaN
# 4    strategicAlignment    0.10     NaN     NaN    NaN    NaN

# %%
AA['ratingA'] = [6,4,3,6,5]

AA['ratingB'] = [2,3,4,6,7]
print(AA)
# Out:
#                criteria  weight  ratingA  ratingB scoreA scoreB
# 0                  risk    0.15        6        2    NaN    NaN
# 1                   ROI    0.15        4        3    NaN    NaN
# 2  customerSatisfaction    0.20        3        4    NaN    NaN
# 3           feasibility    0.40        6        6    NaN    NaN
# 4    strategicAlignment    0.10        5        7    NaN    NaN

# %%
AA['scoreA'] = [0.9,0.6,0.6,2.4,0.5]
AA['scoreB'] = [0.3,0.45,0.8,2.4,0.7]
print(AA)
# Out:
#                criteria  weight  ratingA  ratingB  scoreA  scoreB
# 0                  risk    0.15        6        2     0.9    0.30
# 1                   ROI    0.15        4        3     0.6    0.45
# 2  customerSatisfaction    0.20        3        4     0.6    0.80
# 3           feasibility    0.40        6        6     2.4    2.40
# 4    strategicAlignment    0.10        5        7     0.5    0.70

# %%
totalScoreA=0
totalScoreB=0
for index, row in AA.iterrows():
  totalScoreA+=row['scoreA']
  totalScoreB+=row['scoreB']

print('the total score for A is {:.2f} and for B is {:.2f}'.format(totalScoreA,totalScoreB))
# Out:
# the total score for A is 5.00 and for B is 4.65

# %%
import numpy as np
import matplotlib.pyplot as plt

axisLocations = np.linspace(start=0, stop=2 * np.pi, num =len(AA['ratingA']), endpoint=False)
axisLocations = np.concatenate((axisLocations,[axisLocations[0]]))

ratingsA=AA['ratingA']
ratingsB=AA['ratingB']
ratingsACircular=np.concatenate((ratingsA,[ratingsA[0]]))
ratingsBCircular=np.concatenate((ratingsB,[ratingsB[0]]))

plt.figure(figsize=(8,8))
plt.subplot(polar=True)
plt.plot(axisLocations, ratingsACircular, 'o-', linewidth=2, label='In-house development')
plt.plot(axisLocations, ratingsBCircular, 'd-', linewidth=2, label='Outsource')
plt.title('Project Options Comparison', size=20)
lines, labels = plt.thetagrids(np.degrees(axisLocations), labels=AA['criteria'])
plt.legend()
plt.show()
